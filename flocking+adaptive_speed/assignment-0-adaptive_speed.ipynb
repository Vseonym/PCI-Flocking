# %%
from dataclasses import dataclass
from vi import Agent, Config, Simulation, Vector2
import pygame as pg
import os
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.12.3)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
frame_dir = "frames"
os.makedirs(frame_dir, exist_ok=True)
frame_count = 0

def save_frame(screen):
    global frame_count
    pg.image.save(screen, os.path.join(frame_dir, f"frame_{frame_count:05d}.png"))
    frame_count += 1

# %%
class RecordingSimulation(Simulation):
    def __init__(self, config):
        super().__init__(config)
        self.frame_count = 0
        os.makedirs("frames", exist_ok=True)

    def after_update(self) -> None:
        # Draw everything to the screen
        self._all.draw(self._screen)

        if self.config.visualise_chunks:
            self.__visualise_chunks()

        # Save current frame as an image
        pg.image.save(self._screen, f"frames/frame_{self.frame_count:05d}.png")

        # Update the screen with the new image
        pg.display.flip()

        self._clock.tick(self.config.fps_limit)

        current_fps = self._clock.get_fps()
        if current_fps > 0:
            self._metrics.fps._push(current_fps)

            if self.config.print_fps:
                print(f"FPS: {current_fps:.1f}")  # noqa: T201

        lonely_count = 0
        for agent in self._all:  # assumes self._all is a list or container of agents
            if not list(agent.in_proximity_accuracy()):
                lonely_count += 1

        if lonely_count == 0:
            print(f"✅ Frame {self.frame_count}: All agents have neighbors — full swarm achieved.")
            self.config.swarm_formed = True
        else:
            print(f"⚠️ Frame {self.frame_count}: {lonely_count} lonely agents.")
        
        # Increment a frame counter (you may need to initialize it somewhere)
        self.frame_count += 1

# %%
@dataclass
class FlockingConfig(Config):
    alignment_weight: float = 1.0
    cohesion_weight: float = 0.04
    separation_weight: float = 2.85
    swarm_formed: bool = False

class FlockingAgent(Agent):
    def on_spawn(self):
        self.lonely_multiplier = 5

    def change_position(self):
        self.there_is_no_escape()
        neighbors = list(self.in_proximity_accuracy())
        if not neighbors and not(self.config.swarm_formed):
            self.pos += self.move * self.lonely_multiplier
            return
        elif not neighbors:
            self.pos += self.move
            return
        
        separationVelocity = Vector2() # move away from nearby agents
        alignmentVelocity = Vector2() # match the average direction of nearby agents
        cohesionVelocity = Vector2() # move toward the average position of nearby agents
        num_neighbors = len(neighbors)

        for neighbor, distance in neighbors: # loop trough each nearby agent.
            offset = self.pos - neighbor.pos # a vector pointing away from the neighbor
            if distance > 0:
                separationVelocity += offset / (distance**1.3) # push neighbors away

            alignmentVelocity += neighbor.move # sum al neighbors movement direction
            cohesionVelocity += neighbor.pos # sum all neigbors position

        # take the average of each vector to get a single direction fro each behavior
        separationVelocity /= num_neighbors
        alignmentVelocity /= num_neighbors
        cohesionVelocity = (cohesionVelocity / num_neighbors - self.pos)

        # multiply bt weights
        separationVelocity *= self.config.separation_weight
        alignmentVelocity *= self.config.alignment_weight
        cohesionVelocity *= self.config.cohesion_weight

        # single movement vector for all behaviors
        self.move = (separationVelocity + alignmentVelocity + cohesionVelocity).normalize() * self.config.movement_speed
        self.pos += self.move

(
    RecordingSimulation(
        FlockingConfig(image_rotation = True, movement_speed = 5.0, radius = 50, seed = 777, duration = 10000, fps_limit = 60)
    )
    .batch_spawn_agents(100, FlockingAgent, images=["images/triangle.png"])
    .run()
)
# Out:
# ⚠️ Frame 0: 33 lonely agents.
# ⚠️ Frame 1: 24 lonely agents.
# ⚠️ Frame 2: 14 lonely agents.
# ⚠️ Frame 3: 5 lonely agents.
# ⚠️ Frame 4: 6 lonely agents.
# ⚠️ Frame 5: 6 lonely agents.
# ⚠️ Frame 6: 4 lonely agents.
# ⚠️ Frame 7: 2 lonely agents.
# ⚠️ Frame 8: 1 lonely agents.
# ⚠️ Frame 9: 1 lonely agents.
# ⚠️ Frame 10: 1 lonely agents.
# ⚠️ Frame 11: 1 lonely agents.
# ⚠️ Frame 12: 2 lonely agents.
# ⚠️ Frame 13: 1 lonely agents.
# ⚠️ Frame 14: 1 lonely agents.
# ⚠️ Frame 15: 2 lonely agents.
# ⚠️ Frame 16: 1 lonely agents.
# ⚠️ Frame 17: 1 lonely agents.
# ⚠️ Frame 18: 1 lonely agents.
# ⚠️ Frame 19: 1 lonely agents.
# ✅ Frame 20: All agents have neighbors — full swarm achieved.
# ⚠️ Frame 21: 2 lonely agents.
# ⚠️ Frame 22: 2 lonely agents.
# ⚠️ Frame 23: 3 lonely agents.
# ⚠️ Frame 24: 3 lonely agents.
# ⚠️ Frame 25: 4 lonely agents.
# ⚠️ Frame 26: 3 lonely agents.
# ⚠️ Frame 27: 1 lonely agents.
# ⚠️ Frame 28: 2 lonely agents.
# ⚠️ Frame 29: 2 lonely agents.
# ⚠️ Frame 30: 3 lonely agents.
# ⚠️ Frame 31: 4 lonely agents.
# ⚠️ Frame 32: 4 lonely agents.
# ⚠️ Frame 33: 5 lonely agents.
# ⚠️ Frame 34: 5 lonely agents.
# ⚠️ Frame 35: 5 lonely agents.
# ⚠️ Frame 36: 4 lonely agents.
# ⚠️ Frame 37: 3 lonely agents.
# ⚠️ Frame 38: 1 lonely agents.
# ⚠️ Frame 39: 3 lonely agents.
# ⚠️ Frame 40: 2 lonely agents.
# ⚠️ Frame 41: 4 lonely agents.
# ⚠️ Frame 42: 2 lonely agents.
# ⚠️ Frame 43: 4 lonely agents.
# ⚠️ Frame 44: 2 lonely agents.
# ⚠️ Frame 45: 2 lonely agents.
# ⚠️ Frame 46: 2 lonely agents.
# ⚠️ Frame 47: 2 lonely agents.
# ⚠️ Frame 48: 2 lonely agents.
# ⚠️ Frame 49: 2 lonely agents.
# ⚠️ Frame 50: 2 lonely agents.
# ⚠️ Frame 51: 2 lonely agents.
# ⚠️ Frame 52: 2 lonely agents.
# ⚠️ Frame 53: 2 lonely agents.
# ⚠️ Frame 54: 2 lonely agents.
# ⚠️ Frame 55: 2 lonely agents.
# ⚠️ Frame 56: 2 lonely agents.
# ⚠️ Frame 57: 3 lonely agents.
# ⚠️ Frame 58: 3 lonely agents.
# ⚠️ Frame 59: 3 lonely agents.
# ⚠️ Frame 60: 3 lonely agents.
# ⚠️ Frame 61: 3 lonely agents.
# ⚠️ Frame 62: 3 lonely agents.
# ⚠️ Frame 63: 4 lonely agents.
# ⚠️ Frame 64: 4 lonely agents.
# ⚠️ Frame 65: 4 lonely agents.
# ⚠️ Frame 66: 4 lonely agents.
# ⚠️ Frame 67: 4 lonely agents.
# ⚠️ Frame 68: 4 lonely agents.
# ⚠️ Frame 69: 3 lonely agents.
# ⚠️ Frame 70: 3 lonely agents.
# ⚠️ Frame 71: 3 lonely agents.
# ⚠️ Frame 72: 1 lonely agents.
# ⚠️ Frame 73: 2 lonely agents.
# ⚠️ Frame 74: 1 lonely agents.
# ⚠️ Frame 75: 2 lonely agents.
# ⚠️ Frame 76: 1 lonely agents.
# ⚠️ Frame 77: 2 lonely agents.
# ⚠️ Frame 78: 1 lonely agents.
# ⚠️ Frame 79: 2 lonely agents.
# ⚠️ Frame 80: 1 lonely agents.
# ⚠️ Frame 81: 2 lonely agents.
# ⚠️ Frame 82: 1 lonely agents.
# ⚠️ Frame 83: 2 lonely agents.
# ⚠️ Frame 84: 1 lonely agents.
# ⚠️ Frame 85: 2 lonely agents.
# ⚠️ Frame 86: 1 lonely agents.
# ⚠️ Frame 87: 2 lonely agents.
# ⚠️ Frame 88: 1 lonely agents.
# ⚠️ Frame 89: 1 lonely agents.
# ⚠️ Frame 90: 2 lonely agents.
# ⚠️ Frame 91: 1 lonely agents.
# ⚠️ Frame 92: 2 lonely agents.
# ⚠️ Frame 93: 2 lonely agents.
# ⚠️ Frame 94: 2 lonely agents.
# ⚠️ Frame 95: 2 lonely agents.
# ⚠️ Frame 96: 1 lonely agents.
# ⚠️ Frame 97: 1 lonely agents.
# ⚠️ Frame 98: 3 lonely agents.
# ⚠️ Frame 99: 3 lonely agents.
# ⚠️ Frame 100: 3 lonely agents.
# ⚠️ Frame 101: 2 lonely agents.
# ⚠️ Frame 102: 4 lonely agents.
# ⚠️ Frame 103: 4 lonely agents.
# ⚠️ Frame 104: 4 lonely agents.
# ⚠️ Frame 105: 3 lonely agents.
# ⚠️ Frame 106: 2 lonely agents.
# ✅ Frame 107: All agents have neighbors — full swarm achieved.
# ⚠️ Frame 108: 1 lonely agents.
# ✅ Frame 109: All agents have neighbors — full swarm achieved.
# ✅ Frame 110: All agents have neighbors — full swarm achieved.
# ⚠️ Frame 111: 2 lonely agents.
# ⚠️ Frame 112: 1 lonely agents.
# ⚠️ Frame 113: 1 lonely agents.
# ⚠️ Frame 114: 2 lonely agents.
# ⚠️ Frame 115: 2 lonely agents.
# ⚠️ Frame 116: 2 lonely agents.
# ⚠️ Frame 117: 2 lonely agents.
# ⚠️ Frame 118: 2 lonely agents.
# ⚠️ Frame 119: 1 lonely agents.
# ⚠️ Frame 120: 1 lonely agents.
# ⚠️ Frame 121: 1 lonely agents.
# ✅ Frame 122: All agents have neighbors — full swarm achieved.
# ✅ Frame 123: All agents have neighbors — full swarm achieved.
# ✅ Frame 124: All agents have neighbors — full swarm achieved.
# ✅ Frame 125: All agents have neighbors — full swarm achieved.
# ✅ Frame 126: All agents have neighbors — full swarm achieved.
# ✅ Frame 127: All agents have neighbors — full swarm achieved.
# ✅ Frame 128: All agents have neighbors — full swarm achieved.
# ✅ Frame 129: All agents have neighbors — full swarm achieved.
# ✅ Frame 130: All agents have neighbors — full swarm achieved.
# ✅ Frame 131: All agents have neighbors — full swarm achieved.
# ✅ Frame 132: All agents have neighbors — full swarm achieved.
# ✅ Frame 133: All agents have neighbors — full swarm achieved.
# ✅ Frame 134: All agents have neighbors — full swarm achieved.
# ✅ Frame 135: All agents have neighbors — full swarm achieved.
# ✅ Frame 136: All agents have neighbors — full swarm achieved.
# ✅ Frame 137: All agents have neighbors — full swarm achieved.
# ✅ Frame 138: All agents have neighbors — full swarm achieved.
# ✅ Frame 139: All agents have neighbors — full swarm achieved.
# ✅ Frame 140: All agents have neighbors — full swarm achieved.
# ✅ Frame 141: All agents have neighbors — full swarm achieved.
# ✅ Frame 142: All agents have neighbors — full swarm achieved.
# ⚠️ Frame 143: 1 lonely agents.
# ⚠️ Frame 144: 1 lonely agents.
# ⚠️ Frame 145: 1 lonely agents.
# ⚠️ Frame 146: 1 lonely agents.
# ⚠️ Frame 147: 1 lonely agents.
# ⚠️ Frame 148: 1 lonely agents.
# ⚠️ Frame 149: 1 lonely agents.
# ⚠️ Frame 150: 1 lonely agents.
# ⚠️ Frame 151: 1 lonely agents.
# ⚠️ Frame 152: 1 lonely agents.
# ⚠️ Frame 153: 1 lonely agents.
# ⚠️ Frame 154: 1 lonely agents.
# ⚠️ Frame 155: 1 lonely agents.
# ⚠️ Frame 156: 1 lonely agents.
# ⚠️ Frame 157: 3 lonely agents.
# ⚠️ Frame 158: 4 lonely agents.
# ⚠️ Frame 159: 4 lonely agents.
# ⚠️ Frame 160: 3 lonely agents.
# ⚠️ Frame 161: 3 lonely agents.
# ⚠️ Frame 162: 2 lonely agents.
# ⚠️ Frame 163: 2 lonely agents.
# ⚠️ Frame 164: 2 lonely agents.
# ⚠️ Frame 165: 2 lonely agents.
# ⚠️ Frame 166: 2 lonely agents.
# ⚠️ Frame 167: 2 lonely agents.
# ⚠️ Frame 168: 2 lonely agents.
# ⚠️ Frame 169: 2 lonely agents.
# ⚠️ Frame 170: 1 lonely agents.
# ⚠️ Frame 171: 1 lonely agents.
# ⚠️ Frame 172: 1 lonely agents.
# ⚠️ Frame 173: 2 lonely agents.
# ⚠️ Frame 174: 2 lonely agents.
# ⚠️ Frame 175: 3 lonely agents.
# ⚠️ Frame 176: 3 lonely agents.
# ⚠️ Frame 177: 3 lonely agents.
# ⚠️ Frame 178: 2 lonely agents.
# ⚠️ Frame 179: 3 lonely agents.
# ⚠️ Frame 180: 2 lonely agents.
# ⚠️ Frame 181: 2 lonely agents.
# ⚠️ Frame 182: 2 lonely agents.
# ⚠️ Frame 183: 1 lonely agents.
# ⚠️ Frame 184: 1 lonely agents.
# ⚠️ Frame 185: 2 lonely agents.
# ⚠️ Frame 186: 2 lonely agents.
# ⚠️ Frame 187: 2 lonely agents.
# ⚠️ Frame 188: 2 lonely agents.
# ⚠️ Frame 189: 2 lonely agents.
# ⚠️ Frame 190: 2 lonely agents.
# ⚠️ Frame 191: 4 lonely agents.
# ⚠️ Frame 192: 4 lonely agents.
# ⚠️ Frame 193: 4 lonely agents.
# ⚠️ Frame 194: 5 lonely agents.
# ⚠️ Frame 195: 5 lonely agents.
# ⚠️ Frame 196: 4 lonely agents.
# ⚠️ Frame 197: 4 lonely agents.
# ⚠️ Frame 198: 3 lonely agents.
# ⚠️ Frame 199: 3 lonely agents.
# ⚠️ Frame 200: 3 lonely agents.
# ⚠️ Frame 201: 3 lonely agents.
# ⚠️ Frame 202: 3 lonely agents.
# ⚠️ Frame 203: 3 lonely agents.
# ⚠️ Frame 204: 2 lonely agents.
# ⚠️ Frame 205: 2 lonely agents.
# ⚠️ Frame 206: 1 lonely agents.
# ⚠️ Frame 207: 2 lonely agents.
# ⚠️ Frame 208: 2 lonely agents.
# ⚠️ Frame 209: 2 lonely agents.
# ⚠️ Frame 210: 2 lonely agents.
# ⚠️ Frame 211: 2 lonely agents.
# ⚠️ Frame 212: 2 lonely agents.
# ⚠️ Frame 213: 2 lonely agents.
# ⚠️ Frame 214: 2 lonely agents.
# ⚠️ Frame 215: 2 lonely agents.
# ⚠️ Frame 216: 3 lonely agents.
# ⚠️ Frame 217: 3 lonely agents.
# ⚠️ Frame 218: 3 lonely agents.
# ⚠️ Frame 219: 3 lonely agents.
# ⚠️ Frame 220: 3 lonely agents.
# ⚠️ Frame 221: 3 lonely agents.
# ⚠️ Frame 222: 4 lonely agents.
# ⚠️ Frame 223: 4 lonely agents.
# ⚠️ Frame 224: 4 lonely agents.
# ⚠️ Frame 225: 5 lonely agents.
# ⚠️ Frame 226: 4 lonely agents.
# ⚠️ Frame 227: 4 lonely agents.
# ⚠️ Frame 228: 4 lonely agents.
# ⚠️ Frame 229: 4 lonely agents.
# ⚠️ Frame 230: 4 lonely agents.
# ⚠️ Frame 231: 4 lonely agents.
# ⚠️ Frame 232: 3 lonely agents.
# ⚠️ Frame 233: 3 lonely agents.
# ⚠️ Frame 234: 3 lonely agents.
# ⚠️ Frame 235: 1 lonely agents.
# ⚠️ Frame 236: 1 lonely agents.
# ⚠️ Frame 237: 1 lonely agents.
# ⚠️ Frame 238: 1 lonely agents.
# ⚠️ Frame 239: 1 lonely agents.
# ⚠️ Frame 240: 1 lonely agents.
# ⚠️ Frame 241: 1 lonely agents.
# ⚠️ Frame 242: 1 lonely agents.
# ⚠️ Frame 243: 1 lonely agents.
# ⚠️ Frame 244: 1 lonely agents.
# ⚠️ Frame 245: 1 lonely agents.
# ⚠️ Frame 246: 1 lonely agents.
# ⚠️ Frame 247: 1 lonely agents.
# ⚠️ Frame 248: 1 lonely agents.
# ⚠️ Frame 249: 1 lonely agents.
# ⚠️ Frame 250: 1 lonely agents.
# ⚠️ Frame 251: 1 lonely agents.
# ✅ Frame 252: All agents have neighbors — full swarm achieved.
# ✅ Frame 253: All agents have neighbors — full swarm achieved.
# ✅ Frame 254: All agents have neighbors — full swarm achieved.
# ✅ Frame 255: All agents have neighbors — full swarm achieved.
# ✅ Frame 256: All agents have neighbors — full swarm achieved.
# ✅ Frame 257: All agents have neighbors — full swarm achieved.
# ✅ Frame 258: All agents have neighbors — full swarm achieved.
# ✅ Frame 259: All agents have neighbors — full swarm achieved.
# ✅ Frame 260: All agents have neighbors — full swarm achieved.
# ⚠️ Frame 261: 1 lonely agents.
# ⚠️ Frame 262: 2 lonely agents.
# ⚠️ Frame 263: 2 lonely agents.
# ⚠️ Frame 264: 3 lonely agents.
# ⚠️ Frame 265: 2 lonely agents.
# ⚠️ Frame 266: 1 lonely agents.
# ⚠️ Frame 267: 1 lonely agents.
# ⚠️ Frame 268: 1 lonely agents.
# ⚠️ Frame 269: 1 lonely agents.
# ⚠️ Frame 270: 2 lonely agents.
# ⚠️ Frame 271: 2 lonely agents.
# ⚠️ Frame 272: 1 lonely agents.
# ✅ Frame 273: All agents have neighbors — full swarm achieved.
# ✅ Frame 274: All agents have neighbors — full swarm achieved.
# ✅ Frame 275: All agents have neighbors — full swarm achieved.
# ✅ Frame 276: All agents have neighbors — full swarm achieved.
# ✅ Frame 277: All agents have neighbors — full swarm achieved.
# ✅ Frame 278: All agents have neighbors — full swarm achieved.
# ✅ Frame 279: All agents have neighbors — full swarm achieved.
# ✅ Frame 280: All agents have neighbors — full swarm achieved.
# ✅ Frame 281: All agents have neighbors — full swarm achieved.
# ✅ Frame 282: All agents have neighbors — full swarm achieved.
# ✅ Frame 283: All agents have neighbors — full swarm achieved.
# ✅ Frame 284: All agents have neighbors — full swarm achieved.
# ✅ Frame 285: All agents have neighbors — full swarm achieved.
# ✅ Frame 286: All agents have neighbors — full swarm achieved.
# ✅ Frame 287: All agents have neighbors — full swarm achieved.
# ✅ Frame 288: All agents have neighbors — full swarm achieved.
# ✅ Frame 289: All agents have neighbors — full swarm achieved.
# ✅ Frame 290: All agents have neighbors — full swarm achieved.
# ✅ Frame 291: All agents have neighbors — full swarm achieved.
# ✅ Frame 292: All agents have neighbors — full swarm achieved.
# ✅ Frame 293: All agents have neighbors — full swarm achieved.
# ✅ Frame 294: All agents have neighbors — full swarm achieved.
# ✅ Frame 295: All agents have neighbors — full swarm achieved.
# ✅ Frame 296: All agents have neighbors — full swarm achieved.
# ✅ Frame 297: All agents have neighbors — full swarm achieved.
# ✅ Frame 298: All agents have neighbors — full swarm achieved.
# ✅ Frame 299: All agents have neighbors — full swarm achieved.
# ✅ Frame 300: All agents have neighbors — full swarm achieved.
# ✅ Frame 301: All agents have neighbors — full swarm achieved.
# ✅ Frame 302: All agents have neighbors — full swarm achieved.
# ✅ Frame 303: All agents have neighbors — full swarm achieved.
# ✅ Frame 304: All agents have neighbors — full swarm achieved.
# ✅ Frame 305: All agents have neighbors — full swarm achieved.
# ✅ Frame 306: All agents have neighbors — full swarm achieved.
# ✅ Frame 307: All agents have neighbors — full swarm achieved.
# ✅ Frame 308: All agents have neighbors — full swarm achieved.
# ✅ Frame 309: All agents have neighbors — full swarm achieved.
# ✅ Frame 310: All agents have neighbors — full swarm achieved.
# ✅ Frame 311: All agents have neighbors — full swarm achieved.
# ✅ Frame 312: All agents have neighbors — full swarm achieved.
# ✅ Frame 313: All agents have neighbors — full swarm achieved.
# ✅ Frame 314: All agents have neighbors — full swarm achieved.
# ✅ Frame 315: All agents have neighbors — full swarm achieved.
# ✅ Frame 316: All agents have neighbors — full swarm achieved.
# ✅ Frame 317: All agents have neighbors — full swarm achieved.
# ✅ Frame 318: All agents have neighbors — full swarm achieved.
# ✅ Frame 319: All agents have neighbors — full swarm achieved.
# ✅ Frame 320: All agents have neighbors — full swarm achieved.
# ✅ Frame 321: All agents have neighbors — full swarm achieved.
# ✅ Frame 322: All agents have neighbors — full swarm achieved.
# ✅ Frame 323: All agents have neighbors — full swarm achieved.
# ✅ Frame 324: All agents have neighbors — full swarm achieved.
# ✅ Frame 325: All agents have neighbors — full swarm achieved.
# ✅ Frame 326: All agents have neighbors — full swarm achieved.
# ✅ Frame 327: All agents have neighbors — full swarm achieved.
# ✅ Frame 328: All agents have neighbors — full swarm achieved.
# ✅ Frame 329: All agents have neighbors — full swarm achieved.
# ✅ Frame 330: All agents have neighbors — full swarm achieved.
# ✅ Frame 331: All agents have neighbors — full swarm achieved.
# ✅ Frame 332: All agents have neighbors — full swarm achieved.
# ✅ Frame 333: All agents have neighbors — full swarm achieved.
# ✅ Frame 334: All agents have neighbors — full swarm achieved.
# ✅ Frame 335: All agents have neighbors — full swarm achieved.
# ✅ Frame 336: All agents have neighbors — full swarm achieved.
# ✅ Frame 337: All agents have neighbors — full swarm achieved.
# ✅ Frame 338: All agents have neighbors — full swarm achieved.
# ✅ Frame 339: All agents have neighbors — full swarm achieved.
# ✅ Frame 340: All agents have neighbors — full swarm achieved.
# ✅ Frame 341: All agents have neighbors — full swarm achieved.
# ✅ Frame 342: All agents have neighbors — full swarm achieved.
# ✅ Frame 343: All agents have neighbors — full swarm achieved.
# ✅ Frame 344: All agents have neighbors — full swarm achieved.
# ✅ Frame 345: All agents have neighbors — full swarm achieved.
# ✅ Frame 346: All agents have neighbors — full swarm achieved.
# ✅ Frame 347: All agents have neighbors — full swarm achieved.
# ✅ Frame 348: All agents have neighbors — full swarm achieved.
# ✅ Frame 349: All agents have neighbors — full swarm achieved.
# ✅ Frame 350: All agents have neighbors — full swarm achieved.
# ✅ Frame 351: All agents have neighbors — full swarm achieved.
# ✅ Frame 352: All agents have neighbors — full swarm achieved.
# ✅ Frame 353: All agents have neighbors — full swarm achieved.
# ⚠️ Frame 354: 1 lonely agents.
# ✅ Frame 355: All agents have neighbors — full swarm achieved.
# ✅ Frame 356: All agents have neighbors — full swarm achieved.
# ✅ Frame 357: All agents have neighbors — full swarm achieved.
# ✅ Frame 358: All agents have neighbors — full swarm achieved.
# ✅ Frame 359: All agents have neighbors — full swarm achieved.
# ✅ Frame 360: All agents have neighbors — full swarm achieved.
# ✅ Frame 361: All agents have neighbors — full swarm achieved.
# ✅ Frame 362: All agents have neighbors — full swarm achieved.
# ✅ Frame 363: All agents have neighbors — full swarm achieved.
# ✅ Frame 364: All agents have neighbors — full swarm achieved.
# ✅ Frame 365: All agents have neighbors — full swarm achieved.
# ✅ Frame 366: All agents have neighbors — full swarm achieved.
# ⚠️ Frame 367: 2 lonely agents.
# ⚠️ Frame 368: 2 lonely agents.
# ⚠️ Frame 369: 2 lonely agents.
# ⚠️ Frame 370: 3 lonely agents.
# ⚠️ Frame 371: 3 lonely agents.
# ⚠️ Frame 372: 3 lonely agents.
# ⚠️ Frame 373: 3 lonely agents.
# ⚠️ Frame 374: 1 lonely agents.
# ✅ Frame 375: All agents have neighbors — full swarm achieved.
# ⚠️ Frame 376: 1 lonely agents.
# ⚠️ Frame 377: 1 lonely agents.
# ⚠️ Frame 378: 1 lonely agents.
# ✅ Frame 379: All agents have neighbors — full swarm achieved.
# ✅ Frame 380: All agents have neighbors — full swarm achieved.
# ✅ Frame 381: All agents have neighbors — full swarm achieved.
# ✅ Frame 382: All agents have neighbors — full swarm achieved.
# ✅ Frame 383: All agents have neighbors — full swarm achieved.
# ✅ Frame 384: All agents have neighbors — full swarm achieved.
# ✅ Frame 385: All agents have neighbors — full swarm achieved.
# ✅ Frame 386: All agents have neighbors — full swarm achieved.
# ✅ Frame 387: All agents have neighbors — full swarm achieved.
# ✅ Frame 388: All agents have neighbors — full swarm achieved.
# ✅ Frame 389: All agents have neighbors — full swarm achieved.
# ✅ Frame 390: All agents have neighbors — full swarm achieved.
# ✅ Frame 391: All agents have neighbors — full swarm achieved.
# ⚠️ Frame 392: 2 lonely agents.
# ⚠️ Frame 393: 2 lonely agents.
# ⚠️ Frame 394: 2 lonely agents.
# ⚠️ Frame 395: 2 lonely agents.
# ⚠️ Frame 396: 2 lonely agents.
# ⚠️ Frame 397: 2 lonely agents.
# ⚠️ Frame 398: 3 lonely agents.
# ⚠️ Frame 399: 1 lonely agents.
# ✅ Frame 400: All agents have neighbors — full swarm achieved.
# ✅ Frame 401: All agents have neighbors — full swarm achieved.
# ✅ Frame 402: All agents have neighbors — full swarm achieved.
# ✅ Frame 403: All agents have neighbors — full swarm achieved.
# ✅ Frame 404: All agents have neighbors — full swarm achieved.
# ✅ Frame 405: All agents have neighbors — full swarm achieved.
# ✅ Frame 406: All agents have neighbors — full swarm achieved.
# ✅ Frame 407: All agents have neighbors — full swarm achieved.
# ✅ Frame 408: All agents have neighbors — full swarm achieved.
# ✅ Frame 409: All agents have neighbors — full swarm achieved.
# ✅ Frame 410: All agents have neighbors — full swarm achieved.
# ✅ Frame 411: All agents have neighbors — full swarm achieved.
# ✅ Frame 412: All agents have neighbors — full swarm achieved.
# ✅ Frame 413: All agents have neighbors — full swarm achieved.
# ✅ Frame 414: All agents have neighbors — full swarm achieved.
# ✅ Frame 415: All agents have neighbors — full swarm achieved.
# ✅ Frame 416: All agents have neighbors — full swarm achieved.
# ✅ Frame 417: All agents have neighbors — full swarm achieved.
# ✅ Frame 418: All agents have neighbors — full swarm achieved.
# ✅ Frame 419: All agents have neighbors — full swarm achieved.
# ✅ Frame 420: All agents have neighbors — full swarm achieved.
# ✅ Frame 421: All agents have neighbors — full swarm achieved.
# ⚠️ Frame 422: 1 lonely agents.
# ⚠️ Frame 423: 1 lonely agents.
# ⚠️ Frame 424: 1 lonely agents.
# ⚠️ Frame 425: 1 lonely agents.
# ⚠️ Frame 426: 1 lonely agents.
# ⚠️ Frame 427: 1 lonely agents.
# ⚠️ Frame 428: 1 lonely agents.
# ⚠️ Frame 429: 1 lonely agents.
# ✅ Frame 430: All agents have neighbors — full swarm achieved.
# ✅ Frame 431: All agents have neighbors — full swarm achieved.
# ✅ Frame 432: All agents have neighbors — full swarm achieved.
# ✅ Frame 433: All agents have neighbors — full swarm achieved.
# ✅ Frame 434: All agents have neighbors — full swarm achieved.
# ✅ Frame 435: All agents have neighbors — full swarm achieved.
# ✅ Frame 436: All agents have neighbors — full swarm achieved.
# ✅ Frame 437: All agents have neighbors — full swarm achieved.
# ✅ Frame 438: All agents have neighbors — full swarm achieved.
# ✅ Frame 439: All agents have neighbors — full swarm achieved.
# ✅ Frame 440: All agents have neighbors — full swarm achieved.
# ⚠️ Frame 441: 1 lonely agents.
# ⚠️ Frame 442: 1 lonely agents.
# ⚠️ Frame 443: 1 lonely agents.
# ✅ Frame 444: All agents have neighbors — full swarm achieved.
# ✅ Frame 445: All agents have neighbors — full swarm achieved.
# ✅ Frame 446: All agents have neighbors — full swarm achieved.
# ✅ Frame 447: All agents have neighbors — full swarm achieved.
# ✅ Frame 448: All agents have neighbors — full swarm achieved.
# ✅ Frame 449: All agents have neighbors — full swarm achieved.
# ✅ Frame 450: All agents have neighbors — full swarm achieved.
# ✅ Frame 451: All agents have neighbors — full swarm achieved.
# ✅ Frame 452: All agents have neighbors — full swarm achieved.
# ✅ Frame 453: All agents have neighbors — full swarm achieved.
# ✅ Frame 454: All agents have neighbors — full swarm achieved.
# ✅ Frame 455: All agents have neighbors — full swarm achieved.
# ✅ Frame 456: All agents have neighbors — full swarm achieved.
# ✅ Frame 457: All agents have neighbors — full swarm achieved.
# ✅ Frame 458: All agents have neighbors — full swarm achieved.
# ✅ Frame 459: All agents have neighbors — full swarm achieved.
# ✅ Frame 460: All agents have neighbors — full swarm achieved.
# ✅ Frame 461: All agents have neighbors — full swarm achieved.
# ✅ Frame 462: All agents have neighbors — full swarm achieved.
# ✅ Frame 463: All agents have neighbors — full swarm achieved.
# ✅ Frame 464: All agents have neighbors — full swarm achieved.
# ✅ Frame 465: All agents have neighbors — full swarm achieved.
# ✅ Frame 466: All agents have neighbors — full swarm achieved.
# ✅ Frame 467: All agents have neighbors — full swarm achieved.
# ✅ Frame 468: All agents have neighbors — full swarm achieved.
# ✅ Frame 469: All agents have neighbors — full swarm achieved.
# ✅ Frame 470: All agents have neighbors — full swarm achieved.
# ✅ Frame 471: All agents have neighbors — full swarm achieved.
# ✅ Frame 472: All agents have neighbors — full swarm achieved.
# ✅ Frame 473: All agents have neighbors — full swarm achieved.
# ✅ Frame 474: All agents have neighbors — full swarm achieved.
# ✅ Frame 475: All agents have neighbors — full swarm achieved.
# ✅ Frame 476: All agents have neighbors — full swarm achieved.
# ✅ Frame 477: All agents have neighbors — full swarm achieved.
# ✅ Frame 478: All agents have neighbors — full swarm achieved.
# ✅ Frame 479: All agents have neighbors — full swarm achieved.
# ✅ Frame 480: All agents have neighbors — full swarm achieved.
# ✅ Frame 481: All agents have neighbors — full swarm achieved.
# ✅ Frame 482: All agents have neighbors — full swarm achieved.
# ✅ Frame 483: All agents have neighbors — full swarm achieved.
# ✅ Frame 484: All agents have neighbors — full swarm achieved.
# ✅ Frame 485: All agents have neighbors — full swarm achieved.
# ✅ Frame 486: All agents have neighbors — full swarm achieved.
# ✅ Frame 487: All agents have neighbors — full swarm achieved.
# ✅ Frame 488: All agents have neighbors — full swarm achieved.
# ✅ Frame 489: All agents have neighbors — full swarm achieved.
# ✅ Frame 490: All agents have neighbors — full swarm achieved.
# ✅ Frame 491: All agents have neighbors — full swarm achieved.
# ⚠️ Frame 492: 1 lonely agents.
# ✅ Frame 493: All agents have neighbors — full swarm achieved.
# ✅ Frame 494: All agents have neighbors — full swarm achieved.
# ✅ Frame 495: All agents have neighbors — full swarm achieved.
# ✅ Frame 496: All agents have neighbors — full swarm achieved.
# ✅ Frame 497: All agents have neighbors — full swarm achieved.
# ✅ Frame 498: All agents have neighbors — full swarm achieved.
# ✅ Frame 499: All agents have neighbors — full swarm achieved.
# ✅ Frame 500: All agents have neighbors — full swarm achieved.
# ✅ Frame 501: All agents have neighbors — full swarm achieved.
# ✅ Frame 502: All agents have neighbors — full swarm achieved.
# ✅ Frame 503: All agents have neighbors — full swarm achieved.
# ✅ Frame 504: All agents have neighbors — full swarm achieved.
# ✅ Frame 505: All agents have neighbors — full swarm achieved.
# ✅ Frame 506: All agents have neighbors — full swarm achieved.
# ✅ Frame 507: All agents have neighbors — full swarm achieved.
# ✅ Frame 508: All agents have neighbors — full swarm achieved.
# ✅ Frame 509: All agents have neighbors — full swarm achieved.
# ✅ Frame 510: All agents have neighbors — full swarm achieved.
# ✅ Frame 511: All agents have neighbors — full swarm achieved.
# ✅ Frame 512: All agents have neighbors — full swarm achieved.
# ✅ Frame 513: All agents have neighbors — full swarm achieved.
# ✅ Frame 514: All agents have neighbors — full swarm achieved.
# ✅ Frame 515: All agents have neighbors — full swarm achieved.
# ✅ Frame 516: All agents have neighbors — full swarm achieved.
# ✅ Frame 517: All agents have neighbors — full swarm achieved.
# ✅ Frame 518: All agents have neighbors — full swarm achieved.
# ✅ Frame 519: All agents have neighbors — full swarm achieved.
# ✅ Frame 520: All agents have neighbors — full swarm achieved.
# ✅ Frame 521: All agents have neighbors — full swarm achieved.
# ✅ Frame 522: All agents have neighbors — full swarm achieved.
# ✅ Frame 523: All agents have neighbors — full swarm achieved.
# ✅ Frame 524: All agents have neighbors — full swarm achieved.
# ✅ Frame 525: All agents have neighbors — full swarm achieved.
# ✅ Frame 526: All agents have neighbors — full swarm achieved.
# ✅ Frame 527: All agents have neighbors — full swarm achieved.
# ✅ Frame 528: All agents have neighbors — full swarm achieved.
# ✅ Frame 529: All agents have neighbors — full swarm achieved.
# ✅ Frame 530: All agents have neighbors — full swarm achieved.
# ✅ Frame 531: All agents have neighbors — full swarm achieved.
# ✅ Frame 532: All agents have neighbors — full swarm achieved.
# ✅ Frame 533: All agents have neighbors — full swarm achieved.
# ✅ Frame 534: All agents have neighbors — full swarm achieved.
# ✅ Frame 535: All agents have neighbors — full swarm achieved.
# ✅ Frame 536: All agents have neighbors — full swarm achieved.
# ✅ Frame 537: All agents have neighbors — full swarm achieved.
# ✅ Frame 538: All agents have neighbors — full swarm achieved.
# ✅ Frame 539: All agents have neighbors — full swarm achieved.
# ✅ Frame 540: All agents have neighbors — full swarm achieved.
# ⚠️ Frame 541: 1 lonely agents.
# ⚠️ Frame 542: 1 lonely agents.
# ⚠️ Frame 543: 1 lonely agents.
# ⚠️ Frame 544: 1 lonely agents.
# ⚠️ Frame 545: 1 lonely agents.
# ⚠️ Frame 546: 1 lonely agents.
# ⚠️ Frame 547: 1 lonely agents.
# ⚠️ Frame 548: 1 lonely agents.
# ⚠️ Frame 549: 1 lonely agents.
# ⚠️ Frame 550: 1 lonely agents.
# ✅ Frame 551: All agents have neighbors — full swarm achieved.
# ✅ Frame 552: All agents have neighbors — full swarm achieved.
# ✅ Frame 553: All agents have neighbors — full swarm achieved.
# ✅ Frame 554: All agents have neighbors — full swarm achieved.
# ✅ Frame 555: All agents have neighbors — full swarm achieved.
# ✅ Frame 556: All agents have neighbors — full swarm achieved.
# ⚠️ Frame 557: 1 lonely agents.
# ⚠️ Frame 558: 1 lonely agents.
# ⚠️ Frame 559: 1 lonely agents.
# ✅ Frame 560: All agents have neighbors — full swarm achieved.
# ✅ Frame 561: All agents have neighbors — full swarm achieved.
# ✅ Frame 562: All agents have neighbors — full swarm achieved.
# ✅ Frame 563: All agents have neighbors — full swarm achieved.
# ✅ Frame 564: All agents have neighbors — full swarm achieved.
# ✅ Frame 565: All agents have neighbors — full swarm achieved.
# ✅ Frame 566: All agents have neighbors — full swarm achieved.
# ✅ Frame 567: All agents have neighbors — full swarm achieved.
# ✅ Frame 568: All agents have neighbors — full swarm achieved.
# ✅ Frame 569: All agents have neighbors — full swarm achieved.
# ✅ Frame 570: All agents have neighbors — full swarm achieved.
# ✅ Frame 571: All agents have neighbors — full swarm achieved.
# ✅ Frame 572: All agents have neighbors — full swarm achieved.
# ✅ Frame 573: All agents have neighbors — full swarm achieved.
# ✅ Frame 574: All agents have neighbors — full swarm achieved.
# ✅ Frame 575: All agents have neighbors — full swarm achieved.
# ✅ Frame 576: All agents have neighbors — full swarm achieved.
# ✅ Frame 577: All agents have neighbors — full swarm achieved.
# ✅ Frame 578: All agents have neighbors — full swarm achieved.
# ✅ Frame 579: All agents have neighbors — full swarm achieved.
# ✅ Frame 580: All agents have neighbors — full swarm achieved.
# ✅ Frame 581: All agents have neighbors — full swarm achieved.
# ✅ Frame 582: All agents have neighbors — full swarm achieved.
# ✅ Frame 583: All agents have neighbors — full swarm achieved.
# ✅ Frame 584: All agents have neighbors — full swarm achieved.
# ✅ Frame 585: All agents have neighbors — full swarm achieved.
# ✅ Frame 586: All agents have neighbors — full swarm achieved.
# ⚠️ Frame 587: 1 lonely agents.
# ⚠️ Frame 588: 1 lonely agents.
# ⚠️ Frame 589: 1 lonely agents.
# ⚠️ Frame 590: 1 lonely agents.
# ⚠️ Frame 591: 1 lonely agents.
# ⚠️ Frame 592: 1 lonely agents.
# ⚠️ Frame 593: 1 lonely agents.
# ⚠️ Frame 594: 1 lonely agents.
# ✅ Frame 595: All agents have neighbors — full swarm achieved.
# ✅ Frame 596: All agents have neighbors — full swarm achieved.
# ✅ Frame 597: All agents have neighbors — full swarm achieved.
# ✅ Frame 598: All agents have neighbors — full swarm achieved.
# ✅ Frame 599: All agents have neighbors — full swarm achieved.
# ✅ Frame 600: All agents have neighbors — full swarm achieved.
# ✅ Frame 601: All agents have neighbors — full swarm achieved.
# ✅ Frame 602: All agents have neighbors — full swarm achieved.
# ✅ Frame 603: All agents have neighbors — full swarm achieved.
# ✅ Frame 604: All agents have neighbors — full swarm achieved.
# ✅ Frame 605: All agents have neighbors — full swarm achieved.
# ✅ Frame 606: All agents have neighbors — full swarm achieved.
# ⚠️ Frame 607: 1 lonely agents.
# ✅ Frame 608: All agents have neighbors — full swarm achieved.
# ✅ Frame 609: All agents have neighbors — full swarm achieved.
# ✅ Frame 610: All agents have neighbors — full swarm achieved.
# ✅ Frame 611: All agents have neighbors — full swarm achieved.
# ✅ Frame 612: All agents have neighbors — full swarm achieved.
# ✅ Frame 613: All agents have neighbors — full swarm achieved.
# ✅ Frame 614: All agents have neighbors — full swarm achieved.
# ✅ Frame 615: All agents have neighbors — full swarm achieved.
# ✅ Frame 616: All agents have neighbors — full swarm achieved.
# ✅ Frame 617: All agents have neighbors — full swarm achieved.
# ✅ Frame 618: All agents have neighbors — full swarm achieved.
# ✅ Frame 619: All agents have neighbors — full swarm achieved.
# ✅ Frame 620: All agents have neighbors — full swarm achieved.
# ✅ Frame 621: All agents have neighbors — full swarm achieved.
# ✅ Frame 622: All agents have neighbors — full swarm achieved.
# ✅ Frame 623: All agents have neighbors — full swarm achieved.
# ✅ Frame 624: All agents have neighbors — full swarm achieved.
# ✅ Frame 625: All agents have neighbors — full swarm achieved.
# ✅ Frame 626: All agents have neighbors — full swarm achieved.
# ✅ Frame 627: All agents have neighbors — full swarm achieved.
# ✅ Frame 628: All agents have neighbors — full swarm achieved.
# ✅ Frame 629: All agents have neighbors — full swarm achieved.
# ✅ Frame 630: All agents have neighbors — full swarm achieved.
# ✅ Frame 631: All agents have neighbors — full swarm achieved.
# ✅ Frame 632: All agents have neighbors — full swarm achieved.
# ✅ Frame 633: All agents have neighbors — full swarm achieved.
# ✅ Frame 634: All agents have neighbors — full swarm achieved.
# ✅ Frame 635: All agents have neighbors — full swarm achieved.
# ✅ Frame 636: All agents have neighbors — full swarm achieved.
# ✅ Frame 637: All agents have neighbors — full swarm achieved.
# ✅ Frame 638: All agents have neighbors — full swarm achieved.
# ✅ Frame 639: All agents have neighbors — full swarm achieved.
# ✅ Frame 640: All agents have neighbors — full swarm achieved.
# ✅ Frame 641: All agents have neighbors — full swarm achieved.
# ⚠️ Frame 642: 1 lonely agents.
# ⚠️ Frame 643: 1 lonely agents.
# ⚠️ Frame 644: 1 lonely agents.
# ⚠️ Frame 645: 1 lonely agents.
# ⚠️ Frame 646: 1 lonely agents.
# ⚠️ Frame 647: 1 lonely agents.
# ⚠️ Frame 648: 1 lonely agents.
# ⚠️ Frame 649: 1 lonely agents.
# ⚠️ Frame 650: 1 lonely agents.
# ⚠️ Frame 651: 1 lonely agents.
# ⚠️ Frame 652: 1 lonely agents.
# ⚠️ Frame 653: 1 lonely agents.
# ⚠️ Frame 654: 1 lonely agents.
# ⚠️ Frame 655: 1 lonely agents.
# ⚠️ Frame 656: 1 lonely agents.
# ⚠️ Frame 657: 1 lonely agents.
# ⚠️ Frame 658: 1 lonely agents.
# ✅ Frame 659: All agents have neighbors — full swarm achieved.
# ✅ Frame 660: All agents have neighbors — full swarm achieved.
# ✅ Frame 661: All agents have neighbors — full swarm achieved.
# ✅ Frame 662: All agents have neighbors — full swarm achieved.
# ✅ Frame 663: All agents have neighbors — full swarm achieved.
# ✅ Frame 664: All agents have neighbors — full swarm achieved.
# ✅ Frame 665: All agents have neighbors — full swarm achieved.
# ✅ Frame 666: All agents have neighbors — full swarm achieved.
# ✅ Frame 667: All agents have neighbors — full swarm achieved.
# ✅ Frame 668: All agents have neighbors — full swarm achieved.
# ✅ Frame 669: All agents have neighbors — full swarm achieved.
# ⚠️ Frame 670: 1 lonely agents.
# ⚠️ Frame 671: 1 lonely agents.
# ⚠️ Frame 672: 1 lonely agents.
# ⚠️ Frame 673: 1 lonely agents.
# ✅ Frame 674: All agents have neighbors — full swarm achieved.
# ✅ Frame 675: All agents have neighbors — full swarm achieved.
# ✅ Frame 676: All agents have neighbors — full swarm achieved.
# ✅ Frame 677: All agents have neighbors — full swarm achieved.
# ✅ Frame 678: All agents have neighbors — full swarm achieved.
# ✅ Frame 679: All agents have neighbors — full swarm achieved.
# ✅ Frame 680: All agents have neighbors — full swarm achieved.
# ✅ Frame 681: All agents have neighbors — full swarm achieved.
# ✅ Frame 682: All agents have neighbors — full swarm achieved.
# ✅ Frame 683: All agents have neighbors — full swarm achieved.
# ✅ Frame 684: All agents have neighbors — full swarm achieved.
# ✅ Frame 685: All agents have neighbors — full swarm achieved.
# ✅ Frame 686: All agents have neighbors — full swarm achieved.
# ✅ Frame 687: All agents have neighbors — full swarm achieved.
# ✅ Frame 688: All agents have neighbors — full swarm achieved.
# ✅ Frame 689: All agents have neighbors — full swarm achieved.
# ✅ Frame 690: All agents have neighbors — full swarm achieved.
# ✅ Frame 691: All agents have neighbors — full swarm achieved.
# ✅ Frame 692: All agents have neighbors — full swarm achieved.
# ✅ Frame 693: All agents have neighbors — full swarm achieved.
# ✅ Frame 694: All agents have neighbors — full swarm achieved.
# ✅ Frame 695: All agents have neighbors — full swarm achieved.
# ✅ Frame 696: All agents have neighbors — full swarm achieved.
# ✅ Frame 697: All agents have neighbors — full swarm achieved.
# ✅ Frame 698: All agents have neighbors — full swarm achieved.
# ✅ Frame 699: All agents have neighbors — full swarm achieved.
# ✅ Frame 700: All agents have neighbors — full swarm achieved.
# ✅ Frame 701: All agents have neighbors — full swarm achieved.
# ✅ Frame 702: All agents have neighbors — full swarm achieved.
# ✅ Frame 703: All agents have neighbors — full swarm achieved.
# ✅ Frame 704: All agents have neighbors — full swarm achieved.
# ✅ Frame 705: All agents have neighbors — full swarm achieved.
# ✅ Frame 706: All agents have neighbors — full swarm achieved.
# ✅ Frame 707: All agents have neighbors — full swarm achieved.
# ✅ Frame 708: All agents have neighbors — full swarm achieved.
# ✅ Frame 709: All agents have neighbors — full swarm achieved.
# ✅ Frame 710: All agents have neighbors — full swarm achieved.
# ✅ Frame 711: All agents have neighbors — full swarm achieved.
# ✅ Frame 712: All agents have neighbors — full swarm achieved.
# ✅ Frame 713: All agents have neighbors — full swarm achieved.
# ✅ Frame 714: All agents have neighbors — full swarm achieved.
# ✅ Frame 715: All agents have neighbors — full swarm achieved.
# ✅ Frame 716: All agents have neighbors — full swarm achieved.
# ✅ Frame 717: All agents have neighbors — full swarm achieved.
# ✅ Frame 718: All agents have neighbors — full swarm achieved.
# ✅ Frame 719: All agents have neighbors — full swarm achieved.
# ✅ Frame 720: All agents have neighbors — full swarm achieved.
# ✅ Frame 721: All agents have neighbors — full swarm achieved.
# ✅ Frame 722: All agents have neighbors — full swarm achieved.
# ✅ Frame 723: All agents have neighbors — full swarm achieved.
# ✅ Frame 724: All agents have neighbors — full swarm achieved.
# ✅ Frame 725: All agents have neighbors — full swarm achieved.
# ✅ Frame 726: All agents have neighbors — full swarm achieved.
# ✅ Frame 727: All agents have neighbors — full swarm achieved.
# ✅ Frame 728: All agents have neighbors — full swarm achieved.
# ✅ Frame 729: All agents have neighbors — full swarm achieved.
# ✅ Frame 730: All agents have neighbors — full swarm achieved.
# ✅ Frame 731: All agents have neighbors — full swarm achieved.
# ✅ Frame 732: All agents have neighbors — full swarm achieved.
# ✅ Frame 733: All agents have neighbors — full swarm achieved.
# ✅ Frame 734: All agents have neighbors — full swarm achieved.
# ✅ Frame 735: All agents have neighbors — full swarm achieved.
# ✅ Frame 736: All agents have neighbors — full swarm achieved.
# ✅ Frame 737: All agents have neighbors — full swarm achieved.
# ✅ Frame 738: All agents have neighbors — full swarm achieved.
# ✅ Frame 739: All agents have neighbors — full swarm achieved.
# ✅ Frame 740: All agents have neighbors — full swarm achieved.
# ✅ Frame 741: All agents have neighbors — full swarm achieved.
# ✅ Frame 742: All agents have neighbors — full swarm achieved.
# ✅ Frame 743: All agents have neighbors — full swarm achieved.
# ✅ Frame 744: All agents have neighbors — full swarm achieved.
# ✅ Frame 745: All agents have neighbors — full swarm achieved.
# ✅ Frame 746: All agents have neighbors — full swarm achieved.
# ⚠️ Frame 747: 1 lonely agents.
# ⚠️ Frame 748: 1 lonely agents.
# ⚠️ Frame 749: 1 lonely agents.
# ⚠️ Frame 750: 1 lonely agents.
# ⚠️ Frame 751: 1 lonely agents.
# ⚠️ Frame 752: 1 lonely agents.
# ⚠️ Frame 753: 1 lonely agents.
# ⚠️ Frame 754: 1 lonely agents.
# ⚠️ Frame 755: 1 lonely agents.
# ✅ Frame 756: All agents have neighbors — full swarm achieved.
# ✅ Frame 757: All agents have neighbors — full swarm achieved.
# ✅ Frame 758: All agents have neighbors — full swarm achieved.
# ✅ Frame 759: All agents have neighbors — full swarm achieved.
# ⚠️ Frame 760: 1 lonely agents.
# ⚠️ Frame 761: 1 lonely agents.
# ⚠️ Frame 762: 1 lonely agents.
# ⚠️ Frame 763: 1 lonely agents.
# ⚠️ Frame 764: 1 lonely agents.
# ✅ Frame 765: All agents have neighbors — full swarm achieved.
# ✅ Frame 766: All agents have neighbors — full swarm achieved.
# ✅ Frame 767: All agents have neighbors — full swarm achieved.
# ✅ Frame 768: All agents have neighbors — full swarm achieved.
# ✅ Frame 769: All agents have neighbors — full swarm achieved.
# ✅ Frame 770: All agents have neighbors — full swarm achieved.
# ✅ Frame 771: All agents have neighbors — full swarm achieved.
# ✅ Frame 772: All agents have neighbors — full swarm achieved.
# ✅ Frame 773: All agents have neighbors — full swarm achieved.
# ✅ Frame 774: All agents have neighbors — full swarm achieved.
# ✅ Frame 775: All agents have neighbors — full swarm achieved.
# ✅ Frame 776: All agents have neighbors — full swarm achieved.
# ✅ Frame 777: All agents have neighbors — full swarm achieved.
# ⚠️ Frame 778: 1 lonely agents.
# ✅ Frame 779: All agents have neighbors — full swarm achieved.
# ✅ Frame 780: All agents have neighbors — full swarm achieved.
# ✅ Frame 781: All agents have neighbors — full swarm achieved.
# ✅ Frame 782: All agents have neighbors — full swarm achieved.
# ✅ Frame 783: All agents have neighbors — full swarm achieved.
# ✅ Frame 784: All agents have neighbors — full swarm achieved.
# ✅ Frame 785: All agents have neighbors — full swarm achieved.
# ✅ Frame 786: All agents have neighbors — full swarm achieved.
# ⚠️ Frame 787: 1 lonely agents.
# ⚠️ Frame 788: 1 lonely agents.
# ⚠️ Frame 789: 1 lonely agents.
# ✅ Frame 790: All agents have neighbors — full swarm achieved.
# ✅ Frame 791: All agents have neighbors — full swarm achieved.
# ✅ Frame 792: All agents have neighbors — full swarm achieved.
# ✅ Frame 793: All agents have neighbors — full swarm achieved.
# ✅ Frame 794: All agents have neighbors — full swarm achieved.
# ✅ Frame 795: All agents have neighbors — full swarm achieved.
# ✅ Frame 796: All agents have neighbors — full swarm achieved.
# ✅ Frame 797: All agents have neighbors — full swarm achieved.
# ✅ Frame 798: All agents have neighbors — full swarm achieved.
# ✅ Frame 799: All agents have neighbors — full swarm achieved.
# ✅ Frame 800: All agents have neighbors — full swarm achieved.
# ✅ Frame 801: All agents have neighbors — full swarm achieved.
# ✅ Frame 802: All agents have neighbors — full swarm achieved.
# ✅ Frame 803: All agents have neighbors — full swarm achieved.
# ✅ Frame 804: All agents have neighbors — full swarm achieved.
# ✅ Frame 805: All agents have neighbors — full swarm achieved.
# ✅ Frame 806: All agents have neighbors — full swarm achieved.
# ✅ Frame 807: All agents have neighbors — full swarm achieved.
# ✅ Frame 808: All agents have neighbors — full swarm achieved.
# ✅ Frame 809: All agents have neighbors — full swarm achieved.
# ✅ Frame 810: All agents have neighbors — full swarm achieved.
# ✅ Frame 811: All agents have neighbors — full swarm achieved.
# ✅ Frame 812: All agents have neighbors — full swarm achieved.
# ✅ Frame 813: All agents have neighbors — full swarm achieved.
# ✅ Frame 814: All agents have neighbors — full swarm achieved.
# ✅ Frame 815: All agents have neighbors — full swarm achieved.
# ✅ Frame 816: All agents have neighbors — full swarm achieved.
# ✅ Frame 817: All agents have neighbors — full swarm achieved.
# ✅ Frame 818: All agents have neighbors — full swarm achieved.
# ✅ Frame 819: All agents have neighbors — full swarm achieved.
# ✅ Frame 820: All agents have neighbors — full swarm achieved.
# ✅ Frame 821: All agents have neighbors — full swarm achieved.
# ✅ Frame 822: All agents have neighbors — full swarm achieved.
# ✅ Frame 823: All agents have neighbors — full swarm achieved.
# ✅ Frame 824: All agents have neighbors — full swarm achieved.
# ✅ Frame 825: All agents have neighbors — full swarm achieved.
# ✅ Frame 826: All agents have neighbors — full swarm achieved.
# ✅ Frame 827: All agents have neighbors — full swarm achieved.
# ✅ Frame 828: All agents have neighbors — full swarm achieved.
# ✅ Frame 829: All agents have neighbors — full swarm achieved.
# ✅ Frame 830: All agents have neighbors — full swarm achieved.
# ✅ Frame 831: All agents have neighbors — full swarm achieved.
# ✅ Frame 832: All agents have neighbors — full swarm achieved.
# ✅ Frame 833: All agents have neighbors — full swarm achieved.
# ✅ Frame 834: All agents have neighbors — full swarm achieved.
# ✅ Frame 835: All agents have neighbors — full swarm achieved.
# ✅ Frame 836: All agents have neighbors — full swarm achieved.
# ✅ Frame 837: All agents have neighbors — full swarm achieved.
# ✅ Frame 838: All agents have neighbors — full swarm achieved.
# ✅ Frame 839: All agents have neighbors — full swarm achieved.
# ✅ Frame 840: All agents have neighbors — full swarm achieved.
# ✅ Frame 841: All agents have neighbors — full swarm achieved.
# ✅ Frame 842: All agents have neighbors — full swarm achieved.
# ✅ Frame 843: All agents have neighbors — full swarm achieved.
# ✅ Frame 844: All agents have neighbors — full swarm achieved.
# ✅ Frame 845: All agents have neighbors — full swarm achieved.
# ✅ Frame 846: All agents have neighbors — full swarm achieved.
# ✅ Frame 847: All agents have neighbors — full swarm achieved.
# ✅ Frame 848: All agents have neighbors — full swarm achieved.
# ✅ Frame 849: All agents have neighbors — full swarm achieved.
# ✅ Frame 850: All agents have neighbors — full swarm achieved.
# ✅ Frame 851: All agents have neighbors — full swarm achieved.
# ✅ Frame 852: All agents have neighbors — full swarm achieved.
# ✅ Frame 853: All agents have neighbors — full swarm achieved.
# ✅ Frame 854: All agents have neighbors — full swarm achieved.
# ✅ Frame 855: All agents have neighbors — full swarm achieved.
# ✅ Frame 856: All agents have neighbors — full swarm achieved.
# ✅ Frame 857: All agents have neighbors — full swarm achieved.
# ✅ Frame 858: All agents have neighbors — full swarm achieved.
# ✅ Frame 859: All agents have neighbors — full swarm achieved.
# ✅ Frame 860: All agents have neighbors — full swarm achieved.
# ✅ Frame 861: All agents have neighbors — full swarm achieved.
# ✅ Frame 862: All agents have neighbors — full swarm achieved.
# ✅ Frame 863: All agents have neighbors — full swarm achieved.
# ✅ Frame 864: All agents have neighbors — full swarm achieved.
# ✅ Frame 865: All agents have neighbors — full swarm achieved.
# ✅ Frame 866: All agents have neighbors — full swarm achieved.
# ✅ Frame 867: All agents have neighbors — full swarm achieved.
# ✅ Frame 868: All agents have neighbors — full swarm achieved.
# ✅ Frame 869: All agents have neighbors — full swarm achieved.
# ✅ Frame 870: All agents have neighbors — full swarm achieved.
# ✅ Frame 871: All agents have neighbors — full swarm achieved.
# ✅ Frame 872: All agents have neighbors — full swarm achieved.
# ✅ Frame 873: All agents have neighbors — full swarm achieved.
# ✅ Frame 874: All agents have neighbors — full swarm achieved.
# ✅ Frame 875: All agents have neighbors — full swarm achieved.
# ✅ Frame 876: All agents have neighbors — full swarm achieved.
# ✅ Frame 877: All agents have neighbors — full swarm achieved.
# ✅ Frame 878: All agents have neighbors — full swarm achieved.
# ✅ Frame 879: All agents have neighbors — full swarm achieved.
# ✅ Frame 880: All agents have neighbors — full swarm achieved.
# ✅ Frame 881: All agents have neighbors — full swarm achieved.
# ✅ Frame 882: All agents have neighbors — full swarm achieved.
# ✅ Frame 883: All agents have neighbors — full swarm achieved.
# ✅ Frame 884: All agents have neighbors — full swarm achieved.
# ✅ Frame 885: All agents have neighbors — full swarm achieved.
# ✅ Frame 886: All agents have neighbors — full swarm achieved.
# ✅ Frame 887: All agents have neighbors — full swarm achieved.
# ✅ Frame 888: All agents have neighbors — full swarm achieved.
# ✅ Frame 889: All agents have neighbors — full swarm achieved.
# ✅ Frame 890: All agents have neighbors — full swarm achieved.
# ✅ Frame 891: All agents have neighbors — full swarm achieved.
# ✅ Frame 892: All agents have neighbors — full swarm achieved.
# ✅ Frame 893: All agents have neighbors — full swarm achieved.
# ✅ Frame 894: All agents have neighbors — full swarm achieved.
# ✅ Frame 895: All agents have neighbors — full swarm achieved.
# ✅ Frame 896: All agents have neighbors — full swarm achieved.
# ✅ Frame 897: All agents have neighbors — full swarm achieved.
# ✅ Frame 898: All agents have neighbors — full swarm achieved.
# ✅ Frame 899: All agents have neighbors — full swarm achieved.
# ✅ Frame 900: All agents have neighbors — full swarm achieved.
# ✅ Frame 901: All agents have neighbors — full swarm achieved.
# ✅ Frame 902: All agents have neighbors — full swarm achieved.
# ✅ Frame 903: All agents have neighbors — full swarm achieved.
# ✅ Frame 904: All agents have neighbors — full swarm achieved.
# ✅ Frame 905: All agents have neighbors — full swarm achieved.
# ✅ Frame 906: All agents have neighbors — full swarm achieved.
# ✅ Frame 907: All agents have neighbors — full swarm achieved.
# ⚠️ Frame 908: 1 lonely agents.
# ⚠️ Frame 909: 1 lonely agents.
# ⚠️ Frame 910: 1 lonely agents.
# ⚠️ Frame 911: 1 lonely agents.
# ⚠️ Frame 912: 1 lonely agents.
# ⚠️ Frame 913: 1 lonely agents.
# ⚠️ Frame 914: 1 lonely agents.
# ⚠️ Frame 915: 1 lonely agents.
# ✅ Frame 916: All agents have neighbors — full swarm achieved.
# ✅ Frame 917: All agents have neighbors — full swarm achieved.
# ✅ Frame 918: All agents have neighbors — full swarm achieved.
# ✅ Frame 919: All agents have neighbors — full swarm achieved.
# ✅ Frame 920: All agents have neighbors — full swarm achieved.
# ✅ Frame 921: All agents have neighbors — full swarm achieved.
# ✅ Frame 922: All agents have neighbors — full swarm achieved.
# ✅ Frame 923: All agents have neighbors — full swarm achieved.
# ✅ Frame 924: All agents have neighbors — full swarm achieved.
# ✅ Frame 925: All agents have neighbors — full swarm achieved.
# ✅ Frame 926: All agents have neighbors — full swarm achieved.
# ✅ Frame 927: All agents have neighbors — full swarm achieved.
# ✅ Frame 928: All agents have neighbors — full swarm achieved.
# ✅ Frame 929: All agents have neighbors — full swarm achieved.
# ✅ Frame 930: All agents have neighbors — full swarm achieved.
# ✅ Frame 931: All agents have neighbors — full swarm achieved.
# ✅ Frame 932: All agents have neighbors — full swarm achieved.
# ✅ Frame 933: All agents have neighbors — full swarm achieved.
# ✅ Frame 934: All agents have neighbors — full swarm achieved.
# ✅ Frame 935: All agents have neighbors — full swarm achieved.
# ✅ Frame 936: All agents have neighbors — full swarm achieved.
# ✅ Frame 937: All agents have neighbors — full swarm achieved.
# ✅ Frame 938: All agents have neighbors — full swarm achieved.
# ✅ Frame 939: All agents have neighbors — full swarm achieved.
# ✅ Frame 940: All agents have neighbors — full swarm achieved.
# ✅ Frame 941: All agents have neighbors — full swarm achieved.
# ✅ Frame 942: All agents have neighbors — full swarm achieved.
# ✅ Frame 943: All agents have neighbors — full swarm achieved.
# ✅ Frame 944: All agents have neighbors — full swarm achieved.
# ...
# ✅ Frame 1155: All agents have neighbors — full swarm achieved.
# ✅ Frame 1156: All agents have neighbors — full swarm achieved.
# ✅ Frame 1157: All agents have neighbors — full swarm achieved.
# ✅ Frame 1158: All agents have neighbors — full swarm achieved.
# ✅ Frame 1159: All agents have neighbors — full swarm achieved.
# ✅ Frame 1160: All agents have neighbors — full swarm achieved.
# ✅ Frame 1161: All agents have neighbors — full swarm achieved.
# ✅ Frame 1162: All agents have neighbors — full swarm achieved.
# ✅ Frame 1163: All agents have neighbors — full swarm achieved.
# ✅ Frame 1164: All agents have neighbors — full swarm achieved.
# ✅ Frame 1165: All agents have neighbors — full swarm achieved.
# ✅ Frame 1166: All agents have neighbors — full swarm achieved.
# ✅ Frame 1167: All agents have neighbors — full swarm achieved.
# ✅ Frame 1168: All agents have neighbors — full swarm achieved.
# ✅ Frame 1169: All agents have neighbors — full swarm achieved.
# ✅ Frame 1170: All agents have neighbors — full swarm achieved.
# ✅ Frame 1171: All agents have neighbors — full swarm achieved.
# ✅ Frame 1172: All agents have neighbors — full swarm achieved.
# ✅ Frame 1173: All agents have neighbors — full swarm achieved.
# ✅ Frame 1174: All agents have neighbors — full swarm achieved.
# ✅ Frame 1175: All agents have neighbors — full swarm achieved.
# ✅ Frame 1176: All agents have neighbors — full swarm achieved.
# ✅ Frame 1177: All agents have neighbors — full swarm achieved.
# ✅ Frame 1178: All agents have neighbors — full swarm achieved.
# ✅ Frame 1179: All agents have neighbors — full swarm achieved.
# ✅ Frame 1180: All agents have neighbors — full swarm achieved.
# ✅ Frame 1181: All agents have neighbors — full swarm achieved.
# ✅ Frame 1182: All agents have neighbors — full swarm achieved.
# ✅ Frame 1183: All agents have neighbors — full swarm achieved.
# ✅ Frame 1184: All agents have neighbors — full swarm achieved.
# ✅ Frame 1185: All agents have neighbors — full swarm achieved.
# ✅ Frame 1186: All agents have neighbors — full swarm achieved.
# ✅ Frame 1187: All agents have neighbors — full swarm achieved.
# ✅ Frame 1188: All agents have neighbors — full swarm achieved.
# ✅ Frame 1189: All agents have neighbors — full swarm achieved.
# ✅ Frame 1190: All agents have neighbors — full swarm achieved.
# ✅ Frame 1191: All agents have neighbors — full swarm achieved.
# ✅ Frame 1192: All agents have neighbors — full swarm achieved.
# ✅ Frame 1193: All agents have neighbors — full swarm achieved.
# ✅ Frame 1194: All agents have neighbors — full swarm achieved.
# ✅ Frame 1195: All agents have neighbors — full swarm achieved.
# ✅ Frame 1196: All agents have neighbors — full swarm achieved.
# ✅ Frame 1197: All agents have neighbors — full swarm achieved.
# ✅ Frame 1198: All agents have neighbors — full swarm achieved.
# ✅ Frame 1199: All agents have neighbors — full swarm achieved.
# ✅ Frame 1200: All agents have neighbors — full swarm achieved.
# ✅ Frame 1201: All agents have neighbors — full swarm achieved.
# ✅ Frame 1202: All agents have neighbors — full swarm achieved.
# ✅ Frame 1203: All agents have neighbors — full swarm achieved.
# ✅ Frame 1204: All agents have neighbors — full swarm achieved.
# ✅ Frame 1205: All agents have neighbors — full swarm achieved.
# ✅ Frame 1206: All agents have neighbors — full swarm achieved.
# ✅ Frame 1207: All agents have neighbors — full swarm achieved.
# ✅ Frame 1208: All agents have neighbors — full swarm achieved.
# ✅ Frame 1209: All agents have neighbors — full swarm achieved.
# ✅ Frame 1210: All agents have neighbors — full swarm achieved.
# ✅ Frame 1211: All agents have neighbors — full swarm achieved.
# ✅ Frame 1212: All agents have neighbors — full swarm achieved.
# ✅ Frame 1213: All agents have neighbors — full swarm achieved.
# ✅ Frame 1214: All agents have neighbors — full swarm achieved.
# ✅ Frame 1215: All agents have neighbors — full swarm achieved.
# ✅ Frame 1216: All agents have neighbors — full swarm achieved.
# ✅ Frame 1217: All agents have neighbors — full swarm achieved.
# ✅ Frame 1218: All agents have neighbors — full swarm achieved.
# ✅ Frame 1219: All agents have neighbors — full swarm achieved.
# ✅ Frame 1220: All agents have neighbors — full swarm achieved.
# ⚠️ Frame 1221: 1 lonely agents.
# ⚠️ Frame 1222: 1 lonely agents.
# ⚠️ Frame 1223: 1 lonely agents.
# ⚠️ Frame 1224: 1 lonely agents.
# ⚠️ Frame 1225: 1 lonely agents.
# ⚠️ Frame 1226: 1 lonely agents.
# ⚠️ Frame 1227: 1 lonely agents.
# ⚠️ Frame 1228: 1 lonely agents.
# ⚠️ Frame 1229: 1 lonely agents.
# ✅ Frame 1230: All agents have neighbors — full swarm achieved.
# ✅ Frame 1231: All agents have neighbors — full swarm achieved.
# ✅ Frame 1232: All agents have neighbors — full swarm achieved.
# ✅ Frame 1233: All agents have neighbors — full swarm achieved.
# ✅ Frame 1234: All agents have neighbors — full swarm achieved.
# ✅ Frame 1235: All agents have neighbors — full swarm achieved.
# ✅ Frame 1236: All agents have neighbors — full swarm achieved.
# ✅ Frame 1237: All agents have neighbors — full swarm achieved.
# ✅ Frame 1238: All agents have neighbors — full swarm achieved.
# ✅ Frame 1239: All agents have neighbors — full swarm achieved.
# ✅ Frame 1240: All agents have neighbors — full swarm achieved.
# ✅ Frame 1241: All agents have neighbors — full swarm achieved.
# ✅ Frame 1242: All agents have neighbors — full swarm achieved.
# ✅ Frame 1243: All agents have neighbors — full swarm achieved.
# ✅ Frame 1244: All agents have neighbors — full swarm achieved.
# ✅ Frame 1245: All agents have neighbors — full swarm achieved.
# ✅ Frame 1246: All agents have neighbors — full swarm achieved.
# ✅ Frame 1247: All agents have neighbors — full swarm achieved.
# ✅ Frame 1248: All agents have neighbors — full swarm achieved.
# ✅ Frame 1249: All agents have neighbors — full swarm achieved.
# ✅ Frame 1250: All agents have neighbors — full swarm achieved.
# ✅ Frame 1251: All agents have neighbors — full swarm achieved.
# ✅ Frame 1252: All agents have neighbors — full swarm achieved.
# ✅ Frame 1253: All agents have neighbors — full swarm achieved.
# ✅ Frame 1254: All agents have neighbors — full swarm achieved.
# ✅ Frame 1255: All agents have neighbors — full swarm achieved.
# ✅ Frame 1256: All agents have neighbors — full swarm achieved.
# ✅ Frame 1257: All agents have neighbors — full swarm achieved.
# ✅ Frame 1258: All agents have neighbors — full swarm achieved.
# ✅ Frame 1259: All agents have neighbors — full swarm achieved.
# ✅ Frame 1260: All agents have neighbors — full swarm achieved.
# ✅ Frame 1261: All agents have neighbors — full swarm achieved.
# ✅ Frame 1262: All agents have neighbors — full swarm achieved.
# ✅ Frame 1263: All agents have neighbors — full swarm achieved.
# ✅ Frame 1264: All agents have neighbors — full swarm achieved.
# ✅ Frame 1265: All agents have neighbors — full swarm achieved.
# ✅ Frame 1266: All agents have neighbors — full swarm achieved.
# ✅ Frame 1267: All agents have neighbors — full swarm achieved.
# ✅ Frame 1268: All agents have neighbors — full swarm achieved.
# ✅ Frame 1269: All agents have neighbors — full swarm achieved.
# ✅ Frame 1270: All agents have neighbors — full swarm achieved.
# ✅ Frame 1271: All agents have neighbors — full swarm achieved.
# ✅ Frame 1272: All agents have neighbors — full swarm achieved.
# ✅ Frame 1273: All agents have neighbors — full swarm achieved.
# ✅ Frame 1274: All agents have neighbors — full swarm achieved.
# ✅ Frame 1275: All agents have neighbors — full swarm achieved.
# ✅ Frame 1276: All agents have neighbors — full swarm achieved.
# ✅ Frame 1277: All agents have neighbors — full swarm achieved.
# ✅ Frame 1278: All agents have neighbors — full swarm achieved.
# ✅ Frame 1279: All agents have neighbors — full swarm achieved.
# ✅ Frame 1280: All agents have neighbors — full swarm achieved.
# ✅ Frame 1281: All agents have neighbors — full swarm achieved.
# ✅ Frame 1282: All agents have neighbors — full swarm achieved.
# ✅ Frame 1283: All agents have neighbors — full swarm achieved.
# ✅ Frame 1284: All agents have neighbors — full swarm achieved.
# ✅ Frame 1285: All agents have neighbors — full swarm achieved.
# ✅ Frame 1286: All agents have neighbors — full swarm achieved.
# ✅ Frame 1287: All agents have neighbors — full swarm achieved.
# ✅ Frame 1288: All agents have neighbors — full swarm achieved.
# ✅ Frame 1289: All agents have neighbors — full swarm achieved.
# ✅ Frame 1290: All agents have neighbors — full swarm achieved.
# ✅ Frame 1291: All agents have neighbors — full swarm achieved.
# ✅ Frame 1292: All agents have neighbors — full swarm achieved.
# ✅ Frame 1293: All agents have neighbors — full swarm achieved.
# ✅ Frame 1294: All agents have neighbors — full swarm achieved.
# ✅ Frame 1295: All agents have neighbors — full swarm achieved.
# ✅ Frame 1296: All agents have neighbors — full swarm achieved.
# ✅ Frame 1297: All agents have neighbors — full swarm achieved.
# ✅ Frame 1298: All agents have neighbors — full swarm achieved.
# ✅ Frame 1299: All agents have neighbors — full swarm achieved.
# ✅ Frame 1300: All agents have neighbors — full swarm achieved.
# ✅ Frame 1301: All agents have neighbors — full swarm achieved.
# ✅ Frame 1302: All agents have neighbors — full swarm achieved.
# ✅ Frame 1303: All agents have neighbors — full swarm achieved.
# ✅ Frame 1304: All agents have neighbors — full swarm achieved.
# ✅ Frame 1305: All agents have neighbors — full swarm achieved.
# ✅ Frame 1306: All agents have neighbors — full swarm achieved.
# ✅ Frame 1307: All agents have neighbors — full swarm achieved.
# ✅ Frame 1308: All agents have neighbors — full swarm achieved.
# ✅ Frame 1309: All agents have neighbors — full swarm achieved.
# ✅ Frame 1310: All agents have neighbors — full swarm achieved.
# ✅ Frame 1311: All agents have neighbors — full swarm achieved.
# ✅ Frame 1312: All agents have neighbors — full swarm achieved.
# ✅ Frame 1313: All agents have neighbors — full swarm achieved.
# ✅ Frame 1314: All agents have neighbors — full swarm achieved.
# ✅ Frame 1315: All agents have neighbors — full swarm achieved.
# ✅ Frame 1316: All agents have neighbors — full swarm achieved.
# ✅ Frame 1317: All agents have neighbors — full swarm achieved.
# ✅ Frame 1318: All agents have neighbors — full swarm achieved.
# ✅ Frame 1319: All agents have neighbors — full swarm achieved.
# ✅ Frame 1320: All agents have neighbors — full swarm achieved.
# ✅ Frame 1321: All agents have neighbors — full swarm achieved.
# ✅ Frame 1322: All agents have neighbors — full swarm achieved.
# ✅ Frame 1323: All agents have neighbors — full swarm achieved.
# ✅ Frame 1324: All agents have neighbors — full swarm achieved.
# ✅ Frame 1325: All agents have neighbors — full swarm achieved.
# ✅ Frame 1326: All agents have neighbors — full swarm achieved.
# ✅ Frame 1327: All agents have neighbors — full swarm achieved.
# ✅ Frame 1328: All agents have neighbors — full swarm achieved.
# ✅ Frame 1329: All agents have neighbors — full swarm achieved.
# ✅ Frame 1330: All agents have neighbors — full swarm achieved.
# ✅ Frame 1331: All agents have neighbors — full swarm achieved.
# ✅ Frame 1332: All agents have neighbors — full swarm achieved.
# ✅ Frame 1333: All agents have neighbors — full swarm achieved.
# ✅ Frame 1334: All agents have neighbors — full swarm achieved.
# ✅ Frame 1335: All agents have neighbors — full swarm achieved.
# ✅ Frame 1336: All agents have neighbors — full swarm achieved.
# ✅ Frame 1337: All agents have neighbors — full swarm achieved.
# ✅ Frame 1338: All agents have neighbors — full swarm achieved.
# ✅ Frame 1339: All agents have neighbors — full swarm achieved.
# ✅ Frame 1340: All agents have neighbors — full swarm achieved.
# ✅ Frame 1341: All agents have neighbors — full swarm achieved.
# ✅ Frame 1342: All agents have neighbors — full swarm achieved.
# ✅ Frame 1343: All agents have neighbors — full swarm achieved.
# ✅ Frame 1344: All agents have neighbors — full swarm achieved.
# ✅ Frame 1345: All agents have neighbors — full swarm achieved.
# ✅ Frame 1346: All agents have neighbors — full swarm achieved.
# ✅ Frame 1347: All agents have neighbors — full swarm achieved.
# ✅ Frame 1348: All agents have neighbors — full swarm achieved.
# ✅ Frame 1349: All agents have neighbors — full swarm achieved.
# ✅ Frame 1350: All agents have neighbors — full swarm achieved.
# ✅ Frame 1351: All agents have neighbors — full swarm achieved.
# ✅ Frame 1352: All agents have neighbors — full swarm achieved.
# ✅ Frame 1353: All agents have neighbors — full swarm achieved.
# ✅ Frame 1354: All agents have neighbors — full swarm achieved.
# ✅ Frame 1355: All agents have neighbors — full swarm achieved.
# ✅ Frame 1356: All agents have neighbors — full swarm achieved.
# ✅ Frame 1357: All agents have neighbors — full swarm achieved.
# ✅ Frame 1358: All agents have neighbors — full swarm achieved.
# ✅ Frame 1359: All agents have neighbors — full swarm achieved.
# ✅ Frame 1360: All agents have neighbors — full swarm achieved.
# ✅ Frame 1361: All agents have neighbors — full swarm achieved.
# ✅ Frame 1362: All agents have neighbors — full swarm achieved.
# ✅ Frame 1363: All agents have neighbors — full swarm achieved.
# ✅ Frame 1364: All agents have neighbors — full swarm achieved.
# ✅ Frame 1365: All agents have neighbors — full swarm achieved.
# ✅ Frame 1366: All agents have neighbors — full swarm achieved.
# ✅ Frame 1367: All agents have neighbors — full swarm achieved.
# ✅ Frame 1368: All agents have neighbors — full swarm achieved.
# ✅ Frame 1369: All agents have neighbors — full swarm achieved.
# ✅ Frame 1370: All agents have neighbors — full swarm achieved.
# ✅ Frame 1371: All agents have neighbors — full swarm achieved.
# ✅ Frame 1372: All agents have neighbors — full swarm achieved.
# ✅ Frame 1373: All agents have neighbors — full swarm achieved.
# ✅ Frame 1374: All agents have neighbors — full swarm achieved.
# ✅ Frame 1375: All agents have neighbors — full swarm achieved.
# ✅ Frame 1376: All agents have neighbors — full swarm achieved.
# ✅ Frame 1377: All agents have neighbors — full swarm achieved.
# ✅ Frame 1378: All agents have neighbors — full swarm achieved.
# ✅ Frame 1379: All agents have neighbors — full swarm achieved.
# ✅ Frame 1380: All agents have neighbors — full swarm achieved.
# ✅ Frame 1381: All agents have neighbors — full swarm achieved.
# ✅ Frame 1382: All agents have neighbors — full swarm achieved.
# ✅ Frame 1383: All agents have neighbors — full swarm achieved.
# ✅ Frame 1384: All agents have neighbors — full swarm achieved.
# ✅ Frame 1385: All agents have neighbors — full swarm achieved.
# ✅ Frame 1386: All agents have neighbors — full swarm achieved.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 54
#      46         self.move = (separationVelocity + alignmentVelocity + cohesionVelocity).normalize() * self.config.movement_speed
#      47         self.pos += self.move
#      49 (
#      50     RecordingSimulation(
#      51         FlockingConfig(image_rotation = True, movement_speed = 5.0, radius = 50, seed = 777, duration = 10000, fps_limit = 60)
#      52     )
#      53     .batch_spawn_agents(100, FlockingAgent, images=["images/triangle.png"])
# ---> 54     .run()
#      55 )
#
# File c:\Users\georg\anaconda3\envs\main\Lib\site-packages\vi\simulation.py:311, in HeadlessSimulation.run(self)
#     308 self._running = True
#     310 while self._running:
# --> 311     self.tick()
#     313 return self._metrics
#
# File c:\Users\georg\anaconda3\envs\main\Lib\site-packages\vi\simulation.py:353, in HeadlessSimulation.tick(self)
#     350 # Merge the collected snapshots into the dataframe.
#     351 self._metrics._merge()
# --> 353 self.after_update()
#     355 # If we've reached the duration of the simulation, then stop the simulation.
#     356 if self.config.duration > 0 and self.shared.counter == self.config.duration:
#
# Cell In[4], line 18, in RecordingSimulation.after_update(self)
#      15 pg.image.save(self._screen, f"frames/frame_{self.frame_count:05d}.png")
#      17 # Update the screen with the new image
# ---> 18 pg.display.flip()
#      20 self._clock.tick(self.config.fps_limit)
#      22 current_fps = self._clock.get_fps()
#
# KeyboardInterrupt:
